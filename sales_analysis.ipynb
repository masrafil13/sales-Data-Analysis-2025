# %% [markdown]
# # 🧩 Sales Data Analysis using Python & Excel (2025, Bangalore)

# %% [markdown]
# ### **Objective**
# Analyze and visualize retail sales data for 2025 using Python, Excel, and Tableau to identify trends and growth insights.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned dataset
df = pd.read_excel("cleaned_sales_data_2025.xlsx")

# Display first few rows
df.head()
# Out:
#    Order_ID       Date   Product     Category   Region  Sales  Quantity  \
# 0      1001 2025-04-13  Keyboard  Accessories    Hubli  27945         2
# 1      1002 2025-12-15  Keyboard      Apparel    Hubli  92852         3
# 2      1003 2025-09-28     Shoes      Apparel    Hubli  34217         9
# 3      1004 2025-04-17    Laptop  Electronics   Mysore  10308         7
# 4      1005 2025-03-13  Keyboard      Apparel  Belgaum   7949         4
#
#    Profit
# 0     923
# 1   17412
# 2    5129
# 3   13528
# 4   16617

# %%
# Check data information
df.info()

# Summary statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order_ID  100 non-null    int64
#  1   Date      100 non-null    datetime64[ns]
#  2   Product   100 non-null    object
#  3   Category  100 non-null    object
#  4   Region    100 non-null    object
#  5   Sales     100 non-null    int64
#  6   Quantity  100 non-null    int64
#  7   Profit    100 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 6.4+ KB
#           Order_ID                 Date         Sales    Quantity       Profit
# count   100.000000                  100    100.000000  100.000000    100.00000
# mean   1050.500000  2025-07-14 09:21:36  53994.600000    5.120000   9810.36000
# min    1001.000000  2025-01-02 00:00:00   3150.000000    1.000000    109.00000
# 25%    1025.750000  2025-04-12 06:00:00  26835.500000    3.000000   5050.50000
# ...

# %%
# Add month column for analysis
df['Month'] = df['Date'].dt.strftime('%b')

# Total sales and profit
total_sales = df['Sales'].sum()
total_profit = df['Profit'].sum()

print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
# Out:
# Total Sales: 5399460
# Total Profit: 981036

# %%
# Sales by region
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
sns.barplot(x=region_sales.index, y=region_sales.values)
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
# Monthly trend
monthly_sales = df.groupby('Month')['Sales'].sum().reindex(
    ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
)
monthly_sales.plot(kind='line', marker='o', title="Monthly Sales Trend (2025)")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid()
plt.show()

# %%
# Top products
top_products = df.groupby('Product')['Sales'].sum().sort_values(ascending=False).head(5)
sns.barplot(x=top_products.values, y=top_products.index)
plt.title("Top 5 Products by Sales")
plt.xlabel("Sales")
plt.ylabel("Product")
plt.show()

# %% [markdown]
# ### **Next Steps**
# - Import `cleaned_sales_data_2025.xlsx` into **Tableau**.
# - Create dashboards for:
#   - Revenue Growth (Line Chart)
#   - Sales by Region (Bar/Map Chart)
#   - Top Performing Products (Bar Chart)
#   - Profit vs Sales (Scatter Plot)

# %% [markdown]
# **Author:** Masrafil Mortoza Masum
# **Location:** Bangalore
# **Year:** 2025
